# %%
import numpy as np
import pandas as pd

import ipympl
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from mpl_toolkits.mplot3d import Axes3D

print(matplotlib.get_backend())

import data_util as du
import performance_util as pu
import bayes_classifier as bayes
import naive_bayes_classifier as nb
import knn_classifier as knn
import perceptron_model as pm
import log_model as lm
import flda
from sklearn import svm

from PCA import PCA
import kmeans

# %matplotlib inline
# %matplotlib notebook
# %matplotlib widget
# %matplotlib agg
# Out:
# module://ipympl.backend_nbagg

# %%
data_dir = '../data/Medical_data.csv'
test_data_dir = '../data/test_medical.csv'
random_seed = 1
np.set_printoptions(precision=4)

# %%
label_map = {'HEALTHY':0, 'SURGERY':1, 'MEDICATION':2}
X_train, Y_train = du.load_medical(data_dir, label_map = label_map)
X_test, Y_test = du.load_medical(test_data_dir, label_map = label_map)
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)

print(X_train[:3, :])
print(Y_train[:3, :])
# Out:
# (3000, 3)
# (3000, 1)
# (3000, 3)
# (3000, 1)
# [[ 1.6315 -0.2644  2.5346]
#  [ 0.154   1.4195  1.3331]
#  [ 2.0217  0.262   2.88  ]]
# [[0]
#  [1]
#  [0]]
# F:\Study\7th Sem\ELL 409\Assignment 2\ELL_Assignment2\src\data_util.py:31: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   X = df[['TEST1' , 'TEST2', 'TEST3']].as_matrix()
# F:\Study\7th Sem\ELL 409\Assignment 2\ELL_Assignment2\src\data_util.py:34: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   Y = df[['Health']].as_matrix()

# %% [markdown]
# ### VISUALIZATION

# %%
plt.hist(Y_train, bins = 3)
# Out:
# (array([1000., 1000., 1000.]),
#  array([0.    , 0.6667, 1.3333, 2.    ]),
#  <a list of 3 Patch objects>)

# %%
# %matplotlib widget
fig = plt.figure(figsize=(9,7))

ax = Axes3D(fig, rect=[0, 0, 1, 1], elev=60, azim=54)
# ax = plt.axes(projection='3d')
cax = ax.scatter3D(X_train[:,0], X_train[:,1], X_train[:,2], c = Y_train[:,0])
ax.set_title('Data Distribution')


# cax = ax.imshow(X, interpolation='nearest', cmap=cm.coolwarm)
cbar = fig.colorbar(cax, ticks=[0, 1, 2], shrink = 0.5)
cbar.ax.set_yticklabels(['HEALTHY', 'SURGERY', 'MEDICATION'])

plt.savefig('3d_medical.png')
# Out:
# FigureCanvasNbAgg()

# %% [markdown]
# ### PCA

# %%
pca = PCA(n_components = 2)
pca.fit(X_train)
print(np.sum(pca.explained_variance_ratio_))
# Out:
# 0.9352761773710138

# %%
X_transformed = pca.transform(X_train)

# %matplotlib inline
fig = plt.figure()

cax = plt.scatter(X_transformed[:,0], X_transformed[:,1], c = Y_train[:,0])
plt.title('Data Distribution of Reduced Data')

cbar = fig.colorbar(cax, ticks=[0, 1, 2])
cbar.ax.set_yticklabels(['HEALTHY', 'SURGERY', 'MEDICATION'])
plt.savefig('2d_medical.png')

# %% [markdown]
# ## SUPERVISED LEARNING

# %% [markdown]
# ### Data Preprocessing

# %%
X_train, Y_train, X_dev, Y_dev = du.split_data(X_train, Y_train, train_ratio = 0.75, random_state = random_seed)

print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
print(X_dev.shape)
print(Y_dev.shape)
# Out:
# (2250, 3)
# (2250, 1)
# (3000, 3)
# (3000, 1)
# (750, 3)
# (750, 1)

# %%
# %matplotlib inline
plt.hist(Y_train, bins = 3)
plt.show()
plt.hist(Y_test, bins = 3)
plt.show()
plt.hist(Y_dev, bins = 3)
plt.show()

# %%
# Normalize w.r.t train data
# https://stackoverflow.com/questions/49444262/normalize-data-before-or-after-split-of-training-and-testing-data
# https://stats.stackexchange.com/questions/174823/how-to-apply-standardization-normalization-to-train-and-testset-if-prediction-i

X_train, mu, std = du.normalize(X_train)
X_dev = (X_dev - mu) / std
X_test = (X_test - mu) / std

# %% [markdown]
# #### REDUCTION to 2 COMPONENTS - PCA

# %%
pca_2 = PCA(n_components = 2)
pca_2.fit(X_train)
print(np.sum(pca_2.explained_variance_ratio_))
# Out:
# 0.935310859719806

# %%
X_train_reduced = pca_2.transform(X_train)
X_dev_reduced = pca_2.transform(X_dev)
X_test_reduced = pca_2.transform(X_test)

# %% [markdown]
# ### KNN CLASSIFIER

# %% [markdown]
# ####  3D DATA

# %% [markdown]
# ##### Training and Parameter Tuning

# %%
# (no. of neighbours, minkowski parameter) 
knn_parameters = [(1, 1), (5, 1), (10, 1), (15, 1), 
                  (1, 2), (5, 2), (10, 2), (15, 2),
                  (1, 3), (5, 3), (10, 3), (15, 3), 
                  (1, np.inf), (5, np.inf), (10, np.inf), (15, np.inf), 
                  (1, -np.inf), (5, -np.inf), (10, -np.inf), (15, -np.inf)]

    
for k1,p1 in knn_parameters:
    model = knn.knn_model(k = k1, p = p1)
    model.train(X_train, Y_train)
    Y_pred = model.predict(X_dev)
    
    print("Number of Neighbours = %s , Minkowski Parameter = %s" % (str(k1), str(p1)))
    print("Accuracy on Dev Set = ", pu.model_accuracy(Y_pred, Y_dev))
    print("Precision per Class")
    print(pu.model_precision(Y_pred, Y_dev, 3).T[0, :])
    print("Recall per Class")
    print(pu.model_recall(Y_pred, Y_dev, 3).T[0, :])
    print("F1 Score per Class")
    print(pu.model_f1(Y_pred, Y_dev, 3).T[0, :])
    print("Macro Average Precision, Recall and F1 Score")
    print(pu.model_macro_average(Y_pred, Y_dev, 3))
    print("Micro Average Precision, Recall and F1 Score")
    print(pu.model_micro_average(Y_pred, Y_dev, 3))
    
    print()
    print()
# Out:
# Number of Neighbours = 1 , Minkowski Parameter = 1
# Accuracy on Dev Set =  0.8693333333333333
# Precision per Class
# [0.9024 0.8609 0.8445]
# Recall per Class
# [0.8916 0.8609 0.8553]
# F1 Score per Class
# [0.897  0.8609 0.8499]
# Macro Average Precision, Recall and F1 Score
# [0.8693 0.8693 0.8693]
# Micro Average Precision, Recall and F1 Score
# [0.8693 0.8693 0.8693]
#
#
# Number of Neighbours = 5 , Minkowski Parameter = 1
# Accuracy on Dev Set =  0.9066666666666666
# Precision per Class
# [0.9417 0.8905 0.8898]
# Recall per Class
# [0.9076 0.9173 0.8936]
# F1 Score per Class
# [0.9243 0.9037 0.8917]
# Macro Average Precision, Recall and F1 Score
# [0.9073 0.9062 0.9068]
# Micro Average Precision, Recall and F1 Score
# [0.9067 0.9067 0.9067]
#
#
# Number of Neighbours = 10 , Minkowski Parameter = 1
# Accuracy on Dev Set =  0.9066666666666666
# Precision per Class
# [0.9496 0.8826 0.8918]
# Recall per Class
# [0.9076 0.9323 0.8766]
# F1 Score per Class
# [0.9281 0.9068 0.8841]
# Macro Average Precision, Recall and F1 Score
# [0.908  0.9055 0.9067]
# Micro Average Precision, Recall and F1 Score
# [0.9067 0.9067 0.9067]
#
#
# Number of Neighbours = 15 , Minkowski Parameter = 1
# Accuracy on Dev Set =  0.9093333333333333
# Precision per Class
# [0.9779 0.8834 0.8755]
# Recall per Class
# [0.8876 0.9398 0.8979]
# F1 Score per Class
# [0.9305 0.9107 0.8866]
# Macro Average Precision, Recall and F1 Score
# [0.9123 0.9084 0.9103]
# Micro Average Precision, Recall and F1 Score
# [0.9093 0.9093 0.9093]
#
#
# Number of Neighbours = 1 , Minkowski Parameter = 2
# Accuracy on Dev Set =  0.8733333333333333
# Precision per Class
# [0.9139 0.8587 0.8481]
# Recall per Class
# [0.8956 0.8684 0.8553]
# F1 Score per Class
# [0.9047 0.8636 0.8517]
# Macro Average Precision, Recall and F1 Score
# [0.8736 0.8731 0.8733]
# Micro Average Precision, Recall and F1 Score
# [0.8733 0.8733 0.8733]
#
#
# Number of Neighbours = 5 , Minkowski Parameter = 2
# Accuracy on Dev Set =  0.904
# Precision per Class
# [0.938  0.8869 0.8889]
# Recall per Class
# [0.9116 0.9135 0.8851]
# F1 Score per Class
# [0.9246 0.9    0.887 ]
# Macro Average Precision, Recall and F1 Score
# [0.9046 0.9034 0.904 ]
# Micro Average Precision, Recall and F1 Score
# [0.904 0.904 0.904]
#
#
# Number of Neighbours = 10 , Minkowski Parameter = 2
# Accuracy on Dev Set =  0.9106666666666666
# Precision per Class
# [0.9458 0.8803 0.9115]
# Recall per Class
# [0.9116 0.9398 0.8766]
# F1 Score per Class
# [0.9284 0.9091 0.8937]
# Macro Average Precision, Recall and F1 Score
# [0.9125 0.9094 0.9109]
# Micro Average Precision, Recall and F1 Score
# [0.9107 0.9107 0.9107]
#
#
# Number of Neighbours = 15 , Minkowski Parameter = 2
# Accuracy on Dev Set =  0.916
# Precision per Class
# [0.9736 0.8912 0.8908]
# Recall per Class
# [0.8876 0.9549 0.9021]
# F1 Score per Class
# [0.9286 0.922  0.8964]
# Macro Average Precision, Recall and F1 Score
# [0.9185 0.9149 0.9167]
# Micro Average Precision, Recall and F1 Score
# [0.916 0.916 0.916]
#
#
# Number of Neighbours = 1 , Minkowski Parameter = 3
# Accuracy on Dev Set =  0.8746666666666667
# Precision per Class
# [0.9184 0.8556 0.8511]
# Recall per Class
# [0.9036 0.8684 0.8511]
# F1 Score per Class
# [0.9109 0.8619 0.8511]
# Macro Average Precision, Recall and F1 Score
# [0.875  0.8744 0.8747]
# Micro Average Precision, Recall and F1 Score
# [0.8747 0.8747 0.8747]
#
#
# Number of Neighbours = 5 , Minkowski Parameter = 3
# Accuracy on Dev Set =  0.892
# Precision per Class
# [0.9262 0.8773 0.8734]
# Recall per Class
# [0.9076 0.8872 0.8809]
# F1 Score per Class
# [0.9168 0.8822 0.8771]
# Macro Average Precision, Recall and F1 Score
# [0.8923 0.8919 0.8921]
# Micro Average Precision, Recall and F1 Score
# [0.892 0.892 0.892]
#
#
# Number of Neighbours = 10 , Minkowski Parameter = 3
# Accuracy on Dev Set =  0.908
# Precision per Class
# [0.9414 0.8826 0.9043]
# Recall per Class
# [0.9036 0.9323 0.8851]
# F1 Score per Class
# [0.9221 0.9068 0.8946]
# Macro Average Precision, Recall and F1 Score
# [0.9094 0.907  0.9082]
# Micro Average Precision, Recall and F1 Score
# [0.908 0.908 0.908]
#
#
# Number of Neighbours = 15 , Minkowski Parameter = 3
# Accuracy on Dev Set =  0.9133333333333333
# Precision per Class
# [0.9777 0.8905 0.8807]
# Recall per Class
# [0.8795 0.9474 0.9106]
# F1 Score per Class
# [0.926  0.918  0.8954]
# Macro Average Precision, Recall and F1 Score
# [0.9163 0.9125 0.9144]
# Micro Average Precision, Recall and F1 Score
# [0.9133 0.9133 0.9133]
#
#
# Number of Neighbours = 1 , Minkowski Parameter = inf
# Accuracy on Dev Set =  0.872
# Precision per Class
# [0.918  0.8519 0.8475]
# Recall per Class
# [0.8996 0.8647 0.8511]
# F1 Score per Class
# [0.9087 0.8582 0.8493]
# Macro Average Precision, Recall and F1 Score
# [0.8724 0.8718 0.8721]
# Micro Average Precision, Recall and F1 Score
# [0.872 0.872 0.872]
#
#
# Number of Neighbours = 5 , Minkowski Parameter = inf
# Accuracy on Dev Set =  0.8933333333333333
# Precision per Class
# [0.93   0.8718 0.8803]
# Recall per Class
# [0.9076 0.8947 0.8766]
# F1 Score per Class
# [0.9187 0.8831 0.8785]
# Macro Average Precision, Recall and F1 Score
# [0.8941 0.893  0.8935]
# Micro Average Precision, Recall and F1 Score
# [0.8933 0.8933 0.8933]
#
#
# Number of Neighbours = 10 , Minkowski Parameter = inf
# Accuracy on Dev Set =  0.908
# Precision per Class
# [0.9451 0.8803 0.9039]
# Recall per Class
# [0.8996 0.9398 0.8809]
# F1 Score per Class
# [0.9218 0.9091 0.8922]
# Macro Average Precision, Recall and F1 Score
# [0.9098 0.9068 0.9083]
# Micro Average Precision, Recall and F1 Score
# [0.908 0.908 0.908]
#
#
# Number of Neighbours = 15 , Minkowski Parameter = inf
# Accuracy on Dev Set =  0.9133333333333333
# Precision per Class
# [0.9777 0.8819 0.8908]
# Recall per Class
# [0.8795 0.9549 0.9021]
# F1 Score per Class
# [0.926  0.917  0.8964]
# Macro Average Precision, Recall and F1 Score
# [0.9168 0.9122 0.9145]
# Micro Average Precision, Recall and F1 Score
# [0.9133 0.9133 0.9133]
#
#
# Number of Neighbours = 1 , Minkowski Parameter = -inf
# Accuracy on Dev Set =  0.6333333333333333
# Precision per Class
# [0.66   0.6576 0.5802]
# Recall per Class
# [0.6627 0.6353 0.6   ]
# F1 Score per Class
# [0.6613 0.6463 0.59  ]
# Macro Average Precision, Recall and F1 Score
# [0.6326 0.6327 0.6326]
# Micro Average Precision, Recall and F1 Score
# [0.6333 0.6333 0.6333]
#
#
# Number of Neighbours = 5 , Minkowski Parameter = -inf
# Accuracy on Dev Set =  0.7626666666666667
# Precision per Class
# [0.7563 0.7801 0.7522]
# Recall per Class
# [0.8474 0.7068 0.7362]
# F1 Score per Class
# [0.7992 0.7416 0.7441]
# Macro Average Precision, Recall and F1 Score
# [0.7628 0.7634 0.7631]
# Micro Average Precision, Recall and F1 Score
# [0.7627 0.7627 0.7627]
#
#
# Number of Neighbours = 10 , Minkowski Parameter = -inf
# Accuracy on Dev Set =  0.82
# Precision per Class
# [0.8065 0.834  0.8214]
# Recall per Class
# [0.9036 0.7744 0.783 ]
# F1 Score per Class
# [0.8523 0.8031 0.8017]
# Macro Average Precision, Recall and F1 Score
# [0.8206 0.8203 0.8205]
# Micro Average Precision, Recall and F1 Score
# [0.82 0.82 0.82]
#
#
# Number of Neighbours = 15 , Minkowski Parameter = -inf
# Accuracy on Dev Set =  0.8373333333333334
# Precision per Class
# [0.8042 0.8608 0.8546]
# Recall per Class
# [0.9237 0.7669 0.8255]
# F1 Score per Class
# [0.8598 0.8111 0.8398]
# Macro Average Precision, Recall and F1 Score
# [0.8399 0.8387 0.8393]
# Micro Average Precision, Recall and F1 Score
# [0.8373 0.8373 0.8373]

# %% [markdown]
# #####  Testing

# %%
knn_parameters = [(5, 2)]

for k1,p1 in knn_parameters:
    model = knn.knn_model(k = k1, p = p1)
    model.train(X_train, Y_train)
    Y_pred = model.predict(X_test)
    
    print("Number of Neighbours = %s , Minkowski Parameter = %s" % (str(k1), str(p1)))
    print("Accuracy on Test Set = ", pu.model_accuracy(Y_pred, Y_test))
    print("Precision per Class")
    print(pu.model_precision(Y_pred, Y_test, 3).T[0, :])
    print("Recall per Class")
    print(pu.model_recall(Y_pred, Y_test, 3).T[0, :])
    print("F1 Score per Class")
    print(pu.model_f1(Y_pred, Y_test, 3).T[0, :])
    print("Macro Average Precision, Recall and F1 Score")
    print(pu.model_macro_average(Y_pred, Y_test, 3))
    print("Micro Average Precision, Recall and F1 Score")
    print(pu.model_micro_average(Y_pred, Y_test, 3))
    
    print()
    print()
# Out:
# Number of Neighbours = 5 , Minkowski Parameter = 2
# Accuracy on Test Set =  0.8843333333333333
# Precision per Class
# [0.9477 0.8307 0.8832]
# Recall per Class
# [0.888 0.903 0.862]
# F1 Score per Class
# [0.9169 0.8654 0.8725]
# Macro Average Precision, Recall and F1 Score
# [0.8872 0.8843 0.8858]
# Micro Average Precision, Recall and F1 Score
# [0.8843 0.8843 0.8843]

# %% [markdown]
# ##### Training and Parameter Tuning

# %%
# (no. of neighbours, minkowski parameter) 
knn_parameters = [(1, 1), (5, 1), (10, 1), (15, 1), 
                  (1, 2), (5, 2), (10, 2), (15, 2),
                  (1, 3), (5, 3), (10, 3), (15, 3), 
                  (1, np.inf), (5, np.inf), (10, np.inf), (15, np.inf), 
                  (1, -np.inf), (5, -np.inf), (10, -np.inf), (15, -np.inf)]

np.set_printoptions(precision=4)
    
for k1,p1 in knn_parameters:
    model = knn.knn_model(k = k1, p = p1)
    model.train(X_train_reduced, Y_train)
    Y_pred = model.predict(X_dev_reduced)
    
    print("Number of Neighbours = %s , Minkowski Parameter = %s" % (str(k1), str(p1)))
    print("Accuracy on Dev Set = ", pu.model_accuracy(Y_pred, Y_dev))
    print("Precision per Class")
    print(pu.model_precision(Y_pred, Y_dev, 3).T[0, :])
    print("Recall per Class")
    print(pu.model_recall(Y_pred, Y_dev, 3).T[0, :])
    print("F1 Score per Class")
    print(pu.model_f1(Y_pred, Y_dev, 3).T[0, :])
    print("Macro Average Precision, Recall and F1 Score")
    print(pu.model_macro_average(Y_pred, Y_dev, 3))
    print("Micro Average Precision, Recall and F1 Score")
    print(pu.model_micro_average(Y_pred, Y_dev, 3))
    
    print()
    print()
# Out:
# Number of Neighbours = 1 , Minkowski Parameter = 1
# Accuracy on Dev Set =  0.8213333333333334
# Precision per Class
# [0.8704 0.8427 0.7529]
# Recall per Class
# [0.8635 0.7857 0.817 ]
# F1 Score per Class
# [0.8669 0.8132 0.7837]
# Macro Average Precision, Recall and F1 Score
# [0.822  0.8221 0.8221]
# Micro Average Precision, Recall and F1 Score
# [0.8213 0.8213 0.8213]
#
#
# Number of Neighbours = 5 , Minkowski Parameter = 1
# Accuracy on Dev Set =  0.836
# Precision per Class
# [0.9269 0.8358 0.7605]
# Recall per Class
# [0.8153 0.8421 0.8511]
# F1 Score per Class
# [0.8675 0.839  0.8032]
# Macro Average Precision, Recall and F1 Score
# [0.8411 0.8361 0.8386]
# Micro Average Precision, Recall and F1 Score
# [0.836 0.836 0.836]
#
#
# Number of Neighbours = 10 , Minkowski Parameter = 1
# Accuracy on Dev Set =  0.8573333333333333
# Precision per Class
# [0.9258 0.8316 0.822 ]
# Recall per Class
# [0.8514 0.891  0.8255]
# F1 Score per Class
# [0.887  0.8603 0.8238]
# Macro Average Precision, Recall and F1 Score
# [0.8598 0.856  0.8579]
# Micro Average Precision, Recall and F1 Score
# [0.8573 0.8573 0.8573]
#
#
# Number of Neighbours = 15 , Minkowski Parameter = 1
# Accuracy on Dev Set =  0.852
# Precision per Class
# [0.9761 0.8339 0.7727]
# Recall per Class
# [0.8193 0.8684 0.8681]
# F1 Score per Class
# [0.8908 0.8508 0.8176]
# Macro Average Precision, Recall and F1 Score
# [0.8609 0.8519 0.8564]
# Micro Average Precision, Recall and F1 Score
# [0.852 0.852 0.852]
#
#
# Number of Neighbours = 1 , Minkowski Parameter = 2
# Accuracy on Dev Set =  0.8213333333333334
# Precision per Class
# [0.877  0.8394 0.751 ]
# Recall per Class
# [0.8594 0.7857 0.8213]
# F1 Score per Class
# [0.8682 0.8117 0.7846]
# Macro Average Precision, Recall and F1 Score
# [0.8225 0.8221 0.8223]
# Micro Average Precision, Recall and F1 Score
# [0.8213 0.8213 0.8213]
#
#
# Number of Neighbours = 5 , Minkowski Parameter = 2
# Accuracy on Dev Set =  0.8386666666666667
# Precision per Class
# [0.9234 0.839  0.7663]
# Recall per Class
# [0.8233 0.8421 0.8511]
# F1 Score per Class
# [0.8705 0.8405 0.8065]
# Macro Average Precision, Recall and F1 Score
# [0.8429 0.8388 0.8408]
# Micro Average Precision, Recall and F1 Score
# [0.8387 0.8387 0.8387]
#
#
# Number of Neighbours = 10 , Minkowski Parameter = 2
# Accuracy on Dev Set =  0.8493333333333334
# Precision per Class
# [0.9163 0.8213 0.819 ]
# Recall per Class
# [0.8353 0.8985 0.8085]
# F1 Score per Class
# [0.8739 0.8582 0.8137]
# Macro Average Precision, Recall and F1 Score
# [0.8522 0.8474 0.8498]
# Micro Average Precision, Recall and F1 Score
# [0.8493 0.8493 0.8493]
#
#
# Number of Neighbours = 15 , Minkowski Parameter = 2
# Accuracy on Dev Set =  0.8586666666666667
# Precision per Class
# [0.9761 0.8387 0.7863]
# Recall per Class
# [0.8193 0.8797 0.8766]
# F1 Score per Class
# [0.8908 0.8587 0.829 ]
# Macro Average Precision, Recall and F1 Score
# [0.867  0.8585 0.8627]
# Micro Average Precision, Recall and F1 Score
# [0.8587 0.8587 0.8587]
#
#
# Number of Neighbours = 1 , Minkowski Parameter = 3
# Accuracy on Dev Set =  0.8173333333333334
# Precision per Class
# [0.8664 0.8374 0.751 ]
# Recall per Class
# [0.8594 0.7744 0.8213]
# F1 Score per Class
# [0.8629 0.8047 0.7846]
# Macro Average Precision, Recall and F1 Score
# [0.8183 0.8184 0.8183]
# Micro Average Precision, Recall and F1 Score
# [0.8173 0.8173 0.8173]
#
#
# Number of Neighbours = 5 , Minkowski Parameter = 3
# Accuracy on Dev Set =  0.8426666666666667
# Precision per Class
# [0.9364 0.8376 0.7683]
# Recall per Class
# [0.8273 0.8534 0.8468]
# F1 Score per Class
# [0.8785 0.8454 0.8057]
# Macro Average Precision, Recall and F1 Score
# [0.8474 0.8425 0.845 ]
# Micro Average Precision, Recall and F1 Score
# [0.8427 0.8427 0.8427]
#
#
# Number of Neighbours = 10 , Minkowski Parameter = 3
# Accuracy on Dev Set =  0.848
# Precision per Class
# [0.9167 0.8179 0.8182]
# Recall per Class
# [0.8394 0.8947 0.8043]
# F1 Score per Class
# [0.8763 0.8546 0.8112]
# Macro Average Precision, Recall and F1 Score
# [0.8509 0.8461 0.8485]
# Micro Average Precision, Recall and F1 Score
# [0.848 0.848 0.848]
#
#
# Number of Neighbours = 15 , Minkowski Parameter = 3
# Accuracy on Dev Set =  0.856
# Precision per Class
# [0.9761 0.8333 0.7838]
# Recall per Class
# [0.8193 0.8835 0.8638]
# F1 Score per Class
# [0.8908 0.8577 0.8219]
# Macro Average Precision, Recall and F1 Score
# [0.8644 0.8555 0.8599]
# Micro Average Precision, Recall and F1 Score
# [0.856 0.856 0.856]
#
#
# Number of Neighbours = 1 , Minkowski Parameter = inf
# Accuracy on Dev Set =  0.8186666666666667
# Precision per Class
# [0.8664 0.8402 0.7529]
# Recall per Class
# [0.8594 0.7707 0.8298]
# F1 Score per Class
# [0.8629 0.8039 0.7895]
# Macro Average Precision, Recall and F1 Score
# [0.8198 0.82   0.8199]
# Micro Average Precision, Recall and F1 Score
# [0.8187 0.8187 0.8187]
#
#
# Number of Neighbours = 5 , Minkowski Parameter = inf
# Accuracy on Dev Set =  0.8493333333333334
# Precision per Class
# [0.9375 0.8407 0.7812]
# Recall per Class
# [0.8434 0.8534 0.8511]
# F1 Score per Class
# [0.8879 0.847  0.8147]
# Macro Average Precision, Recall and F1 Score
# [0.8532 0.8493 0.8512]
# Micro Average Precision, Recall and F1 Score
# [0.8493 0.8493 0.8493]
#
#
# Number of Neighbours = 10 , Minkowski Parameter = inf
# Accuracy on Dev Set =  0.8506666666666667
# Precision per Class
# [0.9174 0.8258 0.8155]
# Recall per Class
# [0.8474 0.891  0.8085]
# F1 Score per Class
# [0.881  0.8571 0.812 ]
# Macro Average Precision, Recall and F1 Score
# [0.8529 0.849  0.8509]
# Micro Average Precision, Recall and F1 Score
# [0.8507 0.8507 0.8507]
#
#
# Number of Neighbours = 15 , Minkowski Parameter = inf
# Accuracy on Dev Set =  0.8626666666666667
# Precision per Class
# [0.981  0.8386 0.7922]
# Recall per Class
# [0.8273 0.8985 0.8596]
# F1 Score per Class
# [0.8976 0.8675 0.8245]
# Macro Average Precision, Recall and F1 Score
# [0.8706 0.8618 0.8662]
# Micro Average Precision, Recall and F1 Score
# [0.8627 0.8627 0.8627]
#
#
# Number of Neighbours = 1 , Minkowski Parameter = -inf
# Accuracy on Dev Set =  0.4826666666666667
# Precision per Class
# [0.4676 0.5171 0.4664]
# Recall per Class
# [0.5221 0.4549 0.4723]
# F1 Score per Class
# [0.4934 0.484  0.4693]
# Macro Average Precision, Recall and F1 Score
# [0.4837 0.4831 0.4834]
# Micro Average Precision, Recall and F1 Score
# [0.4827 0.4827 0.4827]
#
#
# Number of Neighbours = 5 , Minkowski Parameter = -inf
# Accuracy on Dev Set =  0.5653333333333334
# Precision per Class
# [0.5234 0.6283 0.5816]
# Recall per Class
# [0.7631 0.4511 0.4851]
# F1 Score per Class
# [0.6209 0.5252 0.529 ]
# Macro Average Precision, Recall and F1 Score
# [0.5778 0.5664 0.572 ]
# Micro Average Precision, Recall and F1 Score
# [0.5653 0.5653 0.5653]
#
#
# Number of Neighbours = 10 , Minkowski Parameter = -inf
# Accuracy on Dev Set =  0.6453333333333333
# Precision per Class
# [0.5785 0.7354 0.6818]
# Recall per Class
# [0.8434 0.5226 0.5745]
# F1 Score per Class
# [0.6863 0.611  0.6236]
# Macro Average Precision, Recall and F1 Score
# [0.6653 0.6468 0.6559]
# Micro Average Precision, Recall and F1 Score
# [0.6453 0.6453 0.6453]
#
#
# Number of Neighbours = 15 , Minkowski Parameter = -inf
# Accuracy on Dev Set =  0.668
# Precision per Class
# [0.5847 0.7869 0.7196]
# Recall per Class
# [0.8876 0.5414 0.5787]
# F1 Score per Class
# [0.7049 0.6414 0.6415]
# Macro Average Precision, Recall and F1 Score
# [0.697  0.6692 0.6828]
# Micro Average Precision, Recall and F1 Score
# [0.668 0.668 0.668]

# %% [markdown]
# #### Performance After PCA decreased using KNN Classifier
# #### KNN BEST PARAMETERS
# #### 3D DATA, k = 5, p = 2

# %% [markdown]
# ### BAYES CLASSIFIER

# %% [markdown]
# #### GMM class conditional distribution

# %%
dimension = X_train.shape[1]

gmm_parameters = [[2, 0.01, 100, dimension, 0.0001],  [2, 0.001, 100, dimension, 0.0001],
                  [2, 0.0001, 100, dimension, 0.0001],[2, 0.00001, 100, dimension, 0.0001],
                  [3, 0.01, 100, dimension, 0.0001],  [3, 0.001, 100, dimension, 0.0001],
                  [3, 0.0001, 100, dimension, 0.0001],[3, 0.00001, 100, dimension, 0.0001],
                  [4, 0.01, 100, dimension, 0.0001],  [4, 0.001, 100, dimension, 0.0001],
                  [4, 0.0001, 100, dimension, 0.0001],[4, 0.00001, 100, dimension, 0.0001],
                  [5, 0.01, 100, dimension, 0.0001],  [5, 0.001, 100, dimension, 0.0001],
                  [5, 0.0001, 100, dimension, 0.0001],[5, 0.00001, 100, dimension, 0.0001],]

    
for par in gmm_parameters:
    model = bayes.bayes_classifier(estimator_type = 'GMM', param = par)
    model.train(X_train, Y_train)
    Y_pred = model.predict(X_dev)
    
    print("Number of Components = %s , Number of max EM iterations = %s" % (str(par[0]), str(par[2])))
    print("Accuracy on Dev Set = ", pu.model_accuracy(Y_pred, Y_dev))
    print("Precision per Class")
    print(pu.model_precision(Y_pred, Y_dev, 3).T[0, :])
    print("Recall per Class")
    print(pu.model_recall(Y_pred, Y_dev, 3).T[0, :])
    print("F1 Score per Class")
    print(pu.model_f1(Y_pred, Y_dev, 3).T[0, :])
    print("Macro Average Precision, Recall and F1 Score")
    print(pu.model_macro_average(Y_pred, Y_dev, 3))
    print("Micro Average Precision, Recall and F1 Score")
    print(pu.model_micro_average(Y_pred, Y_dev, 3))
    
    print()
    print()
# Out:
# Class 0
# Converged after 71 iterations
# Class 1
# Converged after 49 iterations
# Class 2
# Converged after 37 iterations
# Number of Components = 2 , Number of max EM iterations = 100
# Accuracy on Dev Set =  0.912
# Precision per Class
# [0.9662 0.8897 0.8836]
# Recall per Class
# [0.9197 0.9398 0.8723]
# F1 Score per Class
# [0.9424 0.9141 0.8779]
# Macro Average Precision, Recall and F1 Score
# [0.9132 0.9106 0.9119]
# Micro Average Precision, Recall and F1 Score
# [0.912 0.912 0.912]
#
#
# Class 0
# Converged after 86 iterations
# Class 1
# Converged after 57 iterations
# Class 2
# Didn't converge, ran for 100 iterations
# Number of Components = 2 , Number of max EM iterations = 100
# Accuracy on Dev Set =  0.9146666666666666
# Precision per Class
# [0.9703 0.8929 0.8846]
# Recall per Class
# [0.9197 0.9398 0.8809]
# F1 Score per Class
# [0.9443 0.9158 0.8827]
# Macro Average Precision, Recall and F1 Score
# [0.9159 0.9135 0.9147]
# Micro Average Precision, Recall and F1 Score
# [0.9147 0.9147 0.9147]
#
#
# Class 0
# Converged after 28 iterations
# Class 1
# Converged after 61 iterations
# Class 2
# Didn't converge, ran for 100 iterations
# Number of Components = 2 , Number of max EM iterations = 100
# Accuracy on Dev Set =  0.912
# Precision per Class
# [0.9662 0.8897 0.8836]
# Recall per Class
# [0.9197 0.9398 0.8723]
# F1 Score per Class
# [0.9424 0.9141 0.8779]
# Macro Average Precision, Recall and F1 Score
# [0.9132 0.9106 0.9119]
# Micro Average Precision, Recall and F1 Score
# [0.912 0.912 0.912]
#
#
# Class 0
# Converged after 73 iterations
# Class 1
# Converged after 65 iterations
# Class 2
# Didn't converge, ran for 100 iterations
# Number of Components = 2 , Number of max EM iterations = 100
# Accuracy on Dev Set =  0.9146666666666666
# Precision per Class
# [0.9703 0.8929 0.8846]
# Recall per Class
# [0.9197 0.9398 0.8809]
# F1 Score per Class
# [0.9443 0.9158 0.8827]
# Macro Average Precision, Recall and F1 Score
# [0.9159 0.9135 0.9147]
# Micro Average Precision, Recall and F1 Score
# [0.9147 0.9147 0.9147]
#
#
# Class 0
# Converged after 77 iterations
# Class 1
# Didn't converge, ran for 100 iterations
# Class 2
# Didn't converge, ran for 100 iterations
# Number of Components = 3 , Number of max EM iterations = 100
# Accuracy on Dev Set =  0.9186666666666666
# Precision per Class
# [0.9703 0.8964 0.8932]
# Recall per Class
# [0.9197 0.9436 0.8894]
# F1 Score per Class
# [0.9443 0.9194 0.8913]
# Macro Average Precision, Recall and F1 Score
# [0.92   0.9175 0.9188]
# Micro Average Precision, Recall and F1 Score
# [0.9187 0.9187 0.9187]
#
#
# Class 0
# Converged after 98 iterations
# Class 1
# Didn't converge, ran for 100 iterations
# Class 2
# Didn't converge, ran for 100 iterations
# Number of Components = 3 , Number of max EM iterations = 100
# Accuracy on Dev Set =  0.9186666666666666
# Precision per Class
# [0.9662 0.8996 0.8932]
# Recall per Class
# [0.9197 0.9436 0.8894]
# F1 Score per Class
# [0.9424 0.9211 0.8913]
# Macro Average Precision, Recall and F1 Score
# [0.9197 0.9175 0.9186]
# Micro Average Precision, Recall and F1 Score
# [0.9187 0.9187 0.9187]
#
#
# Class 0
# Didn't converge, ran for 100 iterations
# Class 1
# Didn't converge, ran for 100 iterations
# Class 2
# Didn't converge, ran for 100 iterations
# Number of Components = 3 , Number of max EM iterations = 100
# Accuracy on Dev Set =  0.9173333333333333
# Precision per Class
# [0.9662 0.9051 0.8828]
# Recall per Class
# [0.9197 0.9323 0.8979]
# F1 Score per Class
# [0.9424 0.9185 0.8903]
# Macro Average Precision, Recall and F1 Score
# [0.9181 0.9166 0.9173]
# Micro Average Precision, Recall and F1 Score
# [0.9173 0.9173 0.9173]
#
#
# Class 0
# Didn't converge, ran for 100 iterations
# Class 1
# Didn't converge, ran for 100 iterations
# Class 2
# Didn't converge, ran for 100 iterations
# Number of Components = 3 , Number of max EM iterations = 100
# Accuracy on Dev Set =  0.9173333333333333
# Precision per Class
# [0.9662 0.8993 0.8894]
# Recall per Class
# [0.9197 0.9398 0.8894]
# F1 Score per Class
# [0.9424 0.9191 0.8894]
# Macro Average Precision, Recall and F1 Score
# [0.9183 0.9163 0.9173]
# Micro Average Precision, Recall and F1 Score
# [0.9173 0.9173 0.9173]
#
#
# Class 0
# Didn't converge, ran for 100 iterations
# Class 1
# Didn't converge, ran for 100 iterations
# Class 2
# Didn't converge, ran for 100 iterations
# Number of Components = 4 , Number of max EM iterations = 100
# Accuracy on Dev Set =  0.9213333333333333
# Precision per Class
# [0.9664 0.9148 0.8843]
# Recall per Class
# [0.9237 0.9286 0.9106]
# F1 Score per Class
# [0.9446 0.9216 0.8973]
# Macro Average Precision, Recall and F1 Score
# [0.9218 0.921  0.9214]
# Micro Average Precision, Recall and F1 Score
# [0.9213 0.9213 0.9213]
#
#
# Class 0
# Didn't converge, ran for 100 iterations
# Class 1
# Didn't converge, ran for 100 iterations
# Class 2
# Didn't converge, ran for 100 iterations
# Number of Components = 4 , Number of max EM iterations = 100
# Accuracy on Dev Set =  0.916
# Precision per Class
# [0.9582 0.9108 0.8802]
# Recall per Class
# [0.9197 0.9211 0.9064]
# F1 Score per Class
# [0.9385 0.9159 0.8931]
# Macro Average Precision, Recall and F1 Score
# [0.9164 0.9157 0.916 ]
# Micro Average Precision, Recall and F1 Score
# [0.916 0.916 0.916]
#
#
# Class 0
# Didn't converge, ran for 100 iterations
# Class 1
# Didn't converge, ran for 100 iterations
# Class 2
# Didn't converge, ran for 100 iterations
# Number of Components = 4 , Number of max EM iterations = 100
# Accuracy on Dev Set =  0.92
# Precision per Class
# [0.9662 0.9148 0.8807]
# Recall per Class
# [0.9197 0.9286 0.9106]
# F1 Score per Class
# [0.9424 0.9216 0.8954]
# Macro Average Precision, Recall and F1 Score
# [0.9206 0.9196 0.9201]
# Micro Average Precision, Recall and F1 Score
# [0.92 0.92 0.92]
#
#
# Class 0
# Didn't converge, ran for 100 iterations
# Class 1
# Didn't converge, ran for 100 iterations
# Class 2
# Didn't converge, ran for 100 iterations
# Number of Components = 4 , Number of max EM iterations = 100
# Accuracy on Dev Set =  0.9186666666666666
# Precision per Class
# [0.9705 0.8961 0.8932]
# Recall per Class
# [0.9237 0.9398 0.8894]
# F1 Score per Class
# [0.9465 0.9174 0.8913]
# Macro Average Precision, Recall and F1 Score
# [0.9199 0.9176 0.9188]
# Micro Average Precision, Recall and F1 Score
# [0.9187 0.9187 0.9187]
#
#
# Class 0
# Converged after 91 iterations
# Class 1
# Didn't converge, ran for 100 iterations
# Class 2
# Didn't converge, ran for 100 iterations
# Number of Components = 5 , Number of max EM iterations = 100
# Accuracy on Dev Set =  0.9133333333333333
# Precision per Class
# [0.9702 0.8949 0.8787]
# Recall per Class
# [0.9157 0.9286 0.8936]
# F1 Score per Class
# [0.9421 0.9114 0.8861]
# Macro Average Precision, Recall and F1 Score
# [0.9146 0.9126 0.9136]
# Micro Average Precision, Recall and F1 Score
# [0.9133 0.9133 0.9133]
#
#
# Class 0
# Didn't converge, ran for 100 iterations
# Class 1
# Didn't converge, ran for 100 iterations
# Class 2
# Didn't converge, ran for 100 iterations
# Number of Components = 5 , Number of max EM iterations = 100
# Accuracy on Dev Set =  0.916
# Precision per Class
# [0.962  0.9114 0.876 ]
# Recall per Class
# [0.9157 0.9286 0.9021]
# F1 Score per Class
# [0.9383 0.9199 0.8889]
# Macro Average Precision, Recall and F1 Score
# [0.9165 0.9155 0.916 ]
# Micro Average Precision, Recall and F1 Score
# [0.916 0.916 0.916]
#
#
# Class 0
# Didn't converge, ran for 100 iterations
# Class 1
# Didn't converge, ran for 100 iterations
# Class 2
# Didn't converge, ran for 100 iterations
# Number of Components = 5 , Number of max EM iterations = 100
# Accuracy on Dev Set =  0.916
# Precision per Class
# [0.9622 0.8932 0.8961]
# Recall per Class
# [0.9197 0.9436 0.8809]
# F1 Score per Class
# [0.9405 0.9177 0.8884]
# Macro Average Precision, Recall and F1 Score
# [0.9172 0.9147 0.9159]
# Micro Average Precision, Recall and F1 Score
# [0.916 0.916 0.916]
#
#
# Class 0
# Didn't converge, ran for 100 iterations
# Class 1
# Didn't converge, ran for 100 iterations
# Class 2
# Didn't converge, ran for 100 iterations
# Number of Components = 5 , Number of max EM iterations = 100
# Accuracy on Dev Set =  0.92
# Precision per Class
# [0.9664 0.9084 0.887 ]
# Recall per Class
# [0.9237 0.9323 0.9021]
# F1 Score per Class
# [0.9446 0.9202 0.8945]
# Macro Average Precision, Recall and F1 Score
# [0.9206 0.9194 0.92  ]
# Micro Average Precision, Recall and F1 Score
# [0.92 0.92 0.92]

# %% [markdown]
# #### Best Parameters [4, 0.01, 100, dimension, 0.0001]

# %%
best_par = [4, 0.01, 100, dimension, 0.0001]
model = bayes.bayes_classifier(estimator_type = 'GMM', param = best_par)
model.train(X_train, Y_train)
Y_pred = model.predict(X_test)
print("Number of Components = %s , Number of max EM iterations = %s" % (str(par[0]), str(par[2])))
print("Accuracy on Test Set = ", pu.model_accuracy(Y_pred, Y_test))
print("Precision per Class")
print(pu.model_precision(Y_pred, Y_test, 3).T[0, :])
print("Recall per Class")
print(pu.model_recall(Y_pred, Y_test, 3).T[0, :])
print("F1 Score per Class")
print(pu.model_f1(Y_pred, Y_test, 3).T[0, :])
print("Macro Average Precision, Recall and F1 Score")
print(pu.model_macro_average(Y_pred, Y_test, 3))
print("Micro Average Precision, Recall and F1 Score")
print(pu.model_micro_average(Y_pred, Y_test, 3))

print()
print()
# Out:
# Class 0
# Converged after 79 iterations
# Class 1
# Didn't converge, ran for 100 iterations
# Class 2
# Didn't converge, ran for 100 iterations
# Number of Components = 5 , Number of max EM iterations = 100
# Accuracy on Dev Set =  0.9
# Precision per Class
# [0.9604 0.8486 0.8993]
# Recall per Class
# [0.897 0.919 0.884]
# F1 Score per Class
# [0.9276 0.8824 0.8916]
# Macro Average Precision, Recall and F1 Score
# [0.9027 0.9    0.9014]
# Micro Average Precision, Recall and F1 Score
# [0.9 0.9 0.9]

# %% [markdown]
# #### Multinormal class conditional distribution

# %%
dimension = X_train.shape[1]
par = []
model = bayes.bayes_classifier(estimator_type = 'MultiNormal', param = par)
model.train(X_train, Y_train)
Y_pred = model.predict(X_test)
    
print("Accuracy on Test Set = ", pu.model_accuracy(Y_pred, Y_test))
print("Precision per Class")
print(pu.model_precision(Y_pred, Y_test, 3).T[0, :])
print("Recall per Class")
print(pu.model_recall(Y_pred, Y_test, 3).T[0, :])
print("F1 Score per Class")
print(pu.model_f1(Y_pred, Y_test, 3).T[0, :])
print("Macro Average Precision, Recall and F1 Score")
print(pu.model_macro_average(Y_pred, Y_test, 3))
print("Micro Average Precision, Recall and F1 Score")
print(pu.model_micro_average(Y_pred, Y_test, 3))

print()
print()
# Out:
# Class 0
# Class 1
# Class 2
# Accuracy on Test Set =  0.5026666666666667
# Precision per Class
# [0.5006 0.5886 0.4485]
# Recall per Class
# [0.832 0.319 0.357]
# F1 Score per Class
# [0.6251 0.4137 0.3976]
# Macro Average Precision, Recall and F1 Score
# [0.5126 0.5027 0.5076]
# Micro Average Precision, Recall and F1 Score
# [0.5027 0.5027 0.5027]

# %% [markdown]
# #### Parzen Window

# %%
dimension = X_train.shape[1]

parzen_parameters = [['hypercube', 0.25, 3, True], ['hypercube', 0.5, 3, True],
                     ['hypercube', 0.75, 3, True], ['hypercube', 1.0, 3, True],
                     ['gaussian', 0.25, 3, True], ['gaussian', 0.5, 3, True],
                     ['gaussian', 0.75, 3, True], ['gaussian', 1.0, 3, True]]
    
for par in parzen_parameters:
    model = bayes.bayes_classifier(estimator_type = 'Parzen', param = par)
    model.train(X_train, Y_train)
    Y_pred = model.predict(X_dev)
    
    print("Accuracy on Dev Set = ", pu.model_accuracy(Y_pred, Y_dev))
    print("Precision per Class")
    print(pu.model_precision(Y_pred, Y_dev, 3).T[0, :])
    print("Recall per Class")
    print(pu.model_recall(Y_pred, Y_dev, 3).T[0, :])
    print("F1 Score per Class")
    print(pu.model_f1(Y_pred, Y_dev, 3).T[0, :])
    print("Macro Average Precision, Recall and F1 Score")
    print(pu.model_macro_average(Y_pred, Y_dev, 3))
    print("Micro Average Precision, Recall and F1 Score")
    print(pu.model_micro_average(Y_pred, Y_dev, 3))
    
    print()
    print()
# Out:
# Class 0
# Class 1
# Class 2
# Accuracy on Dev Set =  0.7826666666666666
# Precision per Class
# [0.6734 0.8704 0.8865]
# Recall per Class
# [0.9438 0.7068 0.6979]
# F1 Score per Class
# [0.786  0.7801 0.781 ]
# Macro Average Precision, Recall and F1 Score
# [0.8101 0.7828 0.7962]
# Micro Average Precision, Recall and F1 Score
# [0.7827 0.7827 0.7827]
#
#
# Class 0
# Class 1
# Class 2
# Accuracy on Dev Set =  0.9013333333333333
# Precision per Class
# [0.9449 0.8664 0.9009]
# Recall per Class
# [0.8956 0.9511 0.8511]
# F1 Score per Class
# [0.9196 0.9068 0.8753]
# Macro Average Precision, Recall and F1 Score
# [0.9041 0.8993 0.9017]
# Micro Average Precision, Recall and F1 Score
# [0.9013 0.9013 0.9013]
#
#
# Class 0
# Class 1
# Class 2
# Accuracy on Dev Set =  0.8986666666666666
# Precision per Class
# [0.9908 0.8454 0.8816]
# Recall per Class
# [0.8675 0.9662 0.8553]
# F1 Score per Class
# [0.9251 0.9018 0.8683]
# Macro Average Precision, Recall and F1 Score
# [0.9059 0.8963 0.9011]
# Micro Average Precision, Recall and F1 Score
# [0.8987 0.8987 0.8987]
#
#
# Class 0
# Class 1
# Class 2
# Accuracy on Dev Set =  0.884
# Precision per Class
# [0.9953 0.8202 0.8694]
# Recall per Class
# [0.8434 0.9774 0.8213]
# F1 Score per Class
# [0.913  0.8919 0.8446]
# Macro Average Precision, Recall and F1 Score
# [0.8949 0.8807 0.8878]
# Micro Average Precision, Recall and F1 Score
# [0.884 0.884 0.884]
#
#
# Class 0
# Class 1
# Class 2
# Accuracy on Dev Set =  0.908
# Precision per Class
# [1.     0.8502 0.8978]
# Recall per Class
# [0.8755 0.9812 0.8596]
# F1 Score per Class
# [0.9336 0.911  0.8783]
# Macro Average Precision, Recall and F1 Score
# [0.916  0.9054 0.9107]
# Micro Average Precision, Recall and F1 Score
# [0.908 0.908 0.908]
#
#
# Class 0
# Class 1
# Class 2
# Accuracy on Dev Set =  0.8786666666666667
# Precision per Class
# [0.9952 0.8119 0.8643]
# Recall per Class
# [0.8394 0.9737 0.8128]
# F1 Score per Class
# [0.9107 0.8855 0.8377]
# Macro Average Precision, Recall and F1 Score
# [0.8905 0.8753 0.8828]
# Micro Average Precision, Recall and F1 Score
# [0.8787 0.8787 0.8787]
#
#
# Class 0
# Class 1
# Class 2
# Accuracy on Dev Set =  0.864
# Precision per Class
# [0.9816 0.8019 0.8364]
# Recall per Class
# [0.8554 0.9436 0.783 ]
# F1 Score per Class
# [0.9142 0.867  0.8088]
# Macro Average Precision, Recall and F1 Score
# [0.8733 0.8607 0.8669]
# Micro Average Precision, Recall and F1 Score
# [0.864 0.864 0.864]
#
#
# Class 0
# Class 1
# Class 2
# Accuracy on Dev Set =  0.844
# Precision per Class
# [0.9399 0.8042 0.7965]
# Recall per Class
# [0.8795 0.8647 0.783 ]
# F1 Score per Class
# [0.9087 0.8333 0.7897]
# Macro Average Precision, Recall and F1 Score
# [0.8469 0.8424 0.8446]
# Micro Average Precision, Recall and F1 Score
# [0.844 0.844 0.844]

# %% [markdown]
# #### Best Parameters ['gaussian', 0.25, 3, True]

# %%
dimension = X_train.shape[1]
par = ['gaussian', 0.25, 3, True]
model = bayes.bayes_classifier(estimator_type = 'Parzen', param = par)
model.train(X_train, Y_train)
Y_pred = model.predict(X_test)
print("Accuracy on Dev Set = ", pu.model_accuracy(Y_pred, Y_test))
print("Precision per Class")
print(pu.model_precision(Y_pred, Y_test, 3).T[0, :])
print("Recall per Class")
print(pu.model_recall(Y_pred, Y_test, 3).T[0, :])
print("F1 Score per Class")
print(pu.model_f1(Y_pred, Y_test, 3).T[0, :])
print("Macro Average Precision, Recall and F1 Score")
print(pu.model_macro_average(Y_pred, Y_test, 3))
print("Micro Average Precision, Recall and F1 Score")
print(pu.model_micro_average(Y_pred, Y_test, 3))

print()
print()
# Out:
# Class 0
# Class 1
# Class 2
# Accuracy on Dev Set =  0.888
# Precision per Class
# [0.993 0.804 0.9  ]
# Recall per Class
# [0.85  0.968 0.846]
# F1 Score per Class
# [0.9159 0.8784 0.8722]
# Macro Average Precision, Recall and F1 Score
# [0.899  0.888  0.8935]
# Micro Average Precision, Recall and F1 Score
# [0.888 0.888 0.888]

# %% [markdown]
# # Naive Bayes Classifier
# #### GMM Class Conditional Distributions

# %%
import naive_bayes_classifier as nb
dimension = X_train.shape[1]

gmm_parameters = [[[2, 0.01, 100, dimension, 0.0001]]*3, [[2, 0.0001, 100, dimension, 0.0001]]*3,
                  [[3, 0.01, 100, dimension, 0.0001]]*3, [[3, 0.0001, 100, dimension, 0.0001]]*3,
                  [[4, 0.01, 100, dimension, 0.0001]]*3, [[4, 0.0001, 100, dimension, 0.0001]]*3,
                  [[5, 0.01, 100, dimension, 0.0001]]*3, [[5, 0.0001, 100, dimension, 0.0001]]*3,]

distributions = ['GMM', 'GMM', 'GMM']
for par in gmm_parameters:
    model = nb.naive_bayes_classifier(distrib = distributions, param = par)
    model.train(X_train, Y_train)
    Y_pred = model.predict(X_dev)
    
    print("Number of Components = %s , Number of max EM iterations = %s" % (str(par[0]), str(par[2])))
    print("Accuracy on Dev Set = ", pu.model_accuracy(Y_pred, Y_dev))
    print("Precision per Class")
    print(pu.model_precision(Y_pred, Y_dev, 3).T[0, :])
    print("Recall per Class")
    print(pu.model_recall(Y_pred, Y_dev, 3).T[0, :])
    print("F1 Score per Class")
    print(pu.model_f1(Y_pred, Y_dev, 3).T[0, :])
    print("Macro Average Precision, Recall and F1 Score")
    print(pu.model_macro_average(Y_pred, Y_dev, 3))
    print("Micro Average Precision, Recall and F1 Score")
    print(pu.model_micro_average(Y_pred, Y_dev, 3))
    
    print()
    print()
# Out:
# Converged after 2 iterations
# Converged after 2 iterations
# Converged after 15 iterations
# Converged after 4 iterations
# Converged after 2 iterations
# Converged after 2 iterations
# Converged after 2 iterations
# Converged after 2 iterations
# Converged after 2 iterations
# Number of Components = [2, 0.01, 100, 3, 0.0001] , Number of max EM iterations = [2, 0.01, 100, 3, 0.0001]
# Accuracy on Dev Set =  0.9066666666666666
# Precision per Class
# [0.9216 0.9147 0.8819]
# Recall per Class
# [0.9438 0.8872 0.8894]
# F1 Score per Class
# [0.9325 0.9008 0.8856]
# Macro Average Precision, Recall and F1 Score
# [0.9061 0.9068 0.9064]
# Micro Average Precision, Recall and F1 Score
# [0.9067 0.9067 0.9067]
#
#
# Converged after 71 iterations
# Converged after 2 iterations
# Converged after 20 iterations
# Didn't converge, ran for 100 iterations
# Converged after 78 iterations
# Converged after 3 iterations
# Converged after 10 iterations
# Converged after 5 iterations
# Didn't converge, ran for 100 iterations
# Number of Components = [2, 0.0001, 100, 3, 0.0001] , Number of max EM iterations = [2, 0.0001, 100, 3, 0.0001]
# Accuracy on Dev Set =  0.9213333333333333
# Precision per Class
# [0.9628 0.9058 0.8966]
# Recall per Class
# [0.9357 0.9398 0.8851]
# F1 Score per Class
# [0.9491 0.9225 0.8908]
# Macro Average Precision, Recall and F1 Score
# [0.9217 0.9202 0.921 ]
# Micro Average Precision, Recall and F1 Score
# [0.9213 0.9213 0.9213]
#
#
# Didn't converge, ran for 100 iterations
# Converged after 2 iterations
# Didn't converge, ran for 100 iterations
# Converged after 2 iterations
# Converged after 72 iterations
# Converged after 4 iterations
# Converged after 4 iterations
# Converged after 6 iterations
# Converged after 2 iterations
# Number of Components = [3, 0.01, 100, 3, 0.0001] , Number of max EM iterations = [3, 0.01, 100, 3, 0.0001]
# Accuracy on Dev Set =  0.92
# Precision per Class
# [0.9551 0.9029 0.9031]
# Recall per Class
# [0.9398 0.9436 0.8723]
# F1 Score per Class
# [0.9474 0.9228 0.8874]
# Macro Average Precision, Recall and F1 Score
# [0.9204 0.9186 0.9195]
# Micro Average Precision, Recall and F1 Score
# [0.92 0.92 0.92]
#
#
# Didn't converge, ran for 100 iterations
# Converged after 2 iterations
# Converged after 52 iterations
# Didn't converge, ran for 100 iterations
# Didn't converge, ran for 100 iterations
# Converged after 8 iterations
# Converged after 10 iterations
# Converged after 9 iterations
# Didn't converge, ran for 100 iterations
# Number of Components = [3, 0.0001, 100, 3, 0.0001] , Number of max EM iterations = [3, 0.0001, 100, 3, 0.0001]
# Accuracy on Dev Set =  0.9213333333333333
# Precision per Class
# [0.9551 0.9058 0.9039]
# Recall per Class
# [0.9398 0.9398 0.8809]
# F1 Score per Class
# [0.9474 0.9225 0.8922]
# Macro Average Precision, Recall and F1 Score
# [0.9216 0.9202 0.9209]
# Micro Average Precision, Recall and F1 Score
# [0.9213 0.9213 0.9213]
#
#
# Didn't converge, ran for 100 iterations
# Converged after 2 iterations
# Didn't converge, ran for 100 iterations
# Converged after 2 iterations
# Converged after 83 iterations
# Converged after 3 iterations
# Converged after 5 iterations
# Converged after 2 iterations
# Converged after 2 iterations
# Number of Components = [4, 0.01, 100, 3, 0.0001] , Number of max EM iterations = [4, 0.01, 100, 3, 0.0001]
# Accuracy on Dev Set =  0.9173333333333333
# Precision per Class
# [0.9474 0.9025 0.9027]
# Recall per Class
# [0.9398 0.9398 0.8681]
# F1 Score per Class
# [0.9435 0.9208 0.885 ]
# Macro Average Precision, Recall and F1 Score
# [0.9175 0.9159 0.9167]
# Micro Average Precision, Recall and F1 Score
# [0.9173 0.9173 0.9173]
#
#
# Didn't converge, ran for 100 iterations
# Converged after 2 iterations
# Didn't converge, ran for 100 iterations
# Didn't converge, ran for 100 iterations
# Didn't converge, ran for 100 iterations
# Converged after 8 iterations
# Converged after 10 iterations
# Converged after 10 iterations
# Didn't converge, ran for 100 iterations
# Number of Components = [4, 0.0001, 100, 3, 0.0001] , Number of max EM iterations = [4, 0.0001, 100, 3, 0.0001]
# Accuracy on Dev Set =  0.92
# Precision per Class
# [0.9512 0.9061 0.9031]
# Recall per Class
# [0.9398 0.9436 0.8723]
# F1 Score per Class
# [0.9455 0.9245 0.8874]
# Macro Average Precision, Recall and F1 Score
# [0.9201 0.9186 0.9194]
# Micro Average Precision, Recall and F1 Score
# [0.92 0.92 0.92]
#
#
# Didn't converge, ran for 100 iterations
# Converged after 2 iterations
# Converged after 86 iterations
# Converged after 2 iterations
# Converged after 3 iterations
# Converged after 3 iterations
# Converged after 2 iterations
# Converged after 2 iterations
# Converged after 2 iterations
# Number of Components = [5, 0.01, 100, 3, 0.0001] , Number of max EM iterations = [5, 0.01, 100, 3, 0.0001]
# Accuracy on Dev Set =  0.904
# Precision per Class
# [0.9176 0.9112 0.8814]
# Recall per Class
# [0.9398 0.8872 0.8851]
# F1 Score per Class
# [0.9286 0.899  0.8832]
# Macro Average Precision, Recall and F1 Score
# [0.9034 0.904  0.9037]
# Micro Average Precision, Recall and F1 Score
# [0.904 0.904 0.904]
#
#
# Didn't converge, ran for 100 iterations
# Converged after 4 iterations
# Didn't converge, ran for 100 iterations
# Didn't converge, ran for 100 iterations
# Didn't converge, ran for 100 iterations
# Converged after 8 iterations
# Converged after 9 iterations
# Converged after 9 iterations
# Didn't converge, ran for 100 iterations
# Number of Components = [5, 0.0001, 100, 3, 0.0001] , Number of max EM iterations = [5, 0.0001, 100, 3, 0.0001]
# Accuracy on Dev Set =  0.9133333333333333
# Precision per Class
# [0.936  0.9044 0.8991]
# Recall per Class
# [0.9398 0.9248 0.8723]
# F1 Score per Class
# [0.9379 0.9145 0.8855]
# Macro Average Precision, Recall and F1 Score
# [0.9132 0.9123 0.9127]
# Micro Average Precision, Recall and F1 Score
# [0.9133 0.9133 0.9133]

# %% [markdown]
# #### Best Parameters

# %%
best_par = [[3, 0.0001, 100, dimension, 0.0001]]*3
distributions = ['GMM', 'GMM', 'GMM']
model = nb.naive_bayes_classifier(distrib = distributions, param = best_par)
model.train(X_train, Y_train)
Y_pred = model.predict(X_test)
print("Number of Components = %s , Number of max EM iterations = %s" % (str(par[0]), str(par[2])))
print("Accuracy on Dev Set = ", pu.model_accuracy(Y_pred, Y_test))
print("Precision per Class")
print(pu.model_precision(Y_pred, Y_test, 3).T[0, :])
print("Recall per Class")
print(pu.model_recall(Y_pred, Y_test, 3).T[0, :])
print("F1 Score per Class")
print(pu.model_f1(Y_pred, Y_test, 3).T[0, :])
print("Macro Average Precision, Recall and F1 Score")
print(pu.model_macro_average(Y_pred, Y_test, 3))
print("Micro Average Precision, Recall and F1 Score")
print(pu.model_micro_average(Y_pred, Y_test, 3))

print()
print()
# Out:
# Didn't converge, ran for 100 iterations
# Converged after 33 iterations
# Didn't converge, ran for 100 iterations
# Converged after 3 iterations
# Didn't converge, ran for 100 iterations
# Converged after 8 iterations
# Converged after 7 iterations
# Converged after 10 iterations
# Didn't converge, ran for 100 iterations
# Number of Components = ['hypercube', 0.5, 3] , Number of max EM iterations = ['hypercube', 0.5, 3]
# Accuracy on Dev Set =  0.899
# Precision per Class
# [0.9526 0.8432 0.9099]
# Recall per Class
# [0.904 0.925 0.868]
# F1 Score per Class
# [0.9277 0.8822 0.8884]
# Macro Average Precision, Recall and F1 Score
# [0.9019 0.899  0.9004]
# Micro Average Precision, Recall and F1 Score
# [0.899 0.899 0.899]

# %% [markdown]
# #### Parzen Window

# %%
dimension = X_train.shape[1]

parzen_parameters = [[['hypercube', 0.5, 3, True]]*3, [['hypercube', 1.0, 3, True]]*3,
                     [['gaussian', 0.5, 3, True]]*3, [['gaussian', 1.0, 3, True]]*3]

distributions = ['Parzen', 'Parzen', 'Parzen']
for par in parzen_parameters:
    model = nb.naive_bayes_classifier(distrib = ['Parzen', 'Parzen', 'Parzen'], param = par)
    model.train(X_train, Y_train)
    Y_pred = model.predict(X_dev)
    
    print("Accuracy on Dev Set = ", pu.model_accuracy(Y_pred, Y_dev))
    print("Precision per Class")
    print(pu.model_precision(Y_pred, Y_dev, 3).T[0, :])
    print("Recall per Class")
    print(pu.model_recall(Y_pred, Y_dev, 3).T[0, :])
    print("F1 Score per Class")
    print(pu.model_f1(Y_pred, Y_dev, 3).T[0, :])
    print("Macro Average Precision, Recall and F1 Score")
    print(pu.model_macro_average(Y_pred, Y_dev, 3))
    print("Micro Average Precision, Recall and F1 Score")
    print(pu.model_micro_average(Y_pred, Y_dev, 3))
    
    print()
    print()
# Out:
# Accuracy on Dev Set =  0.9
# Precision per Class
# [0.9696 0.8651 0.8745]
# Recall per Class
# [0.8956 0.9398 0.8596]
# F1 Score per Class
# [0.9311 0.9009 0.867 ]
# Macro Average Precision, Recall and F1 Score
# [0.903  0.8983 0.9007]
# Micro Average Precision, Recall and F1 Score
# [0.9 0.9 0.9]
# F:\Study\7th Sem\ELL 409\Assignment 1\ELL409_Assign_1\src\naive_bayes_classifier.py:83: RuntimeWarning: divide by zero encountered in log
#   Q[:, i] = Q[:, i] + np.log(((self.per_class_estimator)[i][j].get_likelihood(np.expand_dims(X_test[:, j], axis = 1)) * (self.prior)[i]).ravel())
# Accuracy on Dev Set =  0.8853333333333333
# Precision per Class
# [0.9954 0.8384 0.8432]
# Recall per Class
# [0.8675 0.9361 0.8468]
# F1 Score per Class
# [0.927  0.8845 0.845 ]
# Macro Average Precision, Recall and F1 Score
# [0.8923 0.8835 0.8879]
# Micro Average Precision, Recall and F1 Score
# [0.8853 0.8853 0.8853]
#
#
# Accuracy on Dev Set =  0.872
# Precision per Class
# [0.9731 0.8333 0.824 ]
# Recall per Class
# [0.8715 0.9211 0.817 ]
# F1 Score per Class
# [0.9195 0.875  0.8205]
# Macro Average Precision, Recall and F1 Score
# [0.8768 0.8699 0.8733]
# Micro Average Precision, Recall and F1 Score
# [0.872 0.872 0.872]
#
#
# Accuracy on Dev Set =  0.792
# Precision per Class
# [0.8014 0.8333 0.746 ]
# Recall per Class
# [0.9076 0.6767 0.8   ]
# F1 Score per Class
# [0.8512 0.7469 0.7721]
# Macro Average Precision, Recall and F1 Score
# [0.7936 0.7948 0.7942]
# Micro Average Precision, Recall and F1 Score
# [0.792 0.792 0.792]

# %% [markdown]
# #### Best Parameters []

# %%
dimension = X_train.shape[1]
par = [['hypercube', 0.5, 3, True]]*3
model = nb.naive_bayes_classifier(distrib = ['Parzen', 'Parzen', 'Parzen'], param = par)
model.train(X_train, Y_train)
Y_pred = model.predict(X_test)
    
print("Accuracy on Dev Set = ", pu.model_accuracy(Y_pred, Y_test))
print("Precision per Class")
print(pu.model_precision(Y_pred, Y_test, 3).T[0, :])
print("Recall per Class")
print(pu.model_recall(Y_pred, Y_test, 3).T[0, :])
print("F1 Score per Class")
print(pu.model_f1(Y_pred, Y_test, 3).T[0, :])
print("Macro Average Precision, Recall and F1 Score")
print(pu.model_macro_average(Y_pred, Y_test, 3))
print("Micro Average Precision, Recall and F1 Score")
print(pu.model_micro_average(Y_pred, Y_test, 3))

print()
print()
# Out:
# F:\Study\7th Sem\ELL 409\Assignment 1\ELL409_Assign_1\src\naive_bayes_classifier.py:83: RuntimeWarning: divide by zero encountered in log
#   Q[:, i] = Q[:, i] + np.log(((self.per_class_estimator)[i][j].get_likelihood(np.expand_dims(X_test[:, j], axis = 1)) * (self.prior)[i]).ravel())
# Accuracy on Dev Set =  0.8926666666666667
# Precision per Class
# [0.965  0.825  0.9046]
# Recall per Class
# [0.882 0.943 0.853]
# F1 Score per Class
# [0.9216 0.8801 0.878 ]
# Macro Average Precision, Recall and F1 Score
# [0.8982 0.8927 0.8954]
# Micro Average Precision, Recall and F1 Score
# [0.8927 0.8927 0.8927]

# %% [markdown]
# # Unsupervised Learning
# ## K-Means

# %%
dimension = X_train.shape[1]
iterations = [10, 20, 40, 80, 100, 200, 300, 500, 750, 1000, 2000, 5000, 10000]
for i in iterations:
    print (i)
    model = kmeans.kmeans(3, i)
    model.train(X_train)
    Y_pred = model.predict(X_test)
    Y_pred = np.reshape(Y_pred, (Y_pred.shape[0], 1))
    print("Accuracy on Dev Set = ", pu.model_accuracy(Y_pred, Y_test))
    print("Precision per Class")
    print(pu.model_precision(Y_pred, Y_test, 3).T[0, :])
    print("Recall per Class")
    print(pu.model_recall(Y_pred, Y_test, 3).T[0, :])
    print("F1 Score per Class")
    print(pu.model_f1(Y_pred, Y_test, 3).T[0, :])
    print("Macro Average Precision, Recall and F1 Score")
    print(pu.model_macro_average(Y_pred, Y_test, 3))
    print("Micro Average Precision, Recall and F1 Score")
    print(pu.model_micro_average(Y_pred, Y_test, 3))

    print()
    print()
# Out:
# 10
# Accuracy on Dev Set =  0.32566666666666666
# Precision per Class
# [0.438  0.5349 0.    ]
# Recall per Class
# [0.364 0.613 0.   ]
# F1 Score per Class
# [0.3976 0.5713    nan]
# Macro Average Precision, Recall and F1 Score
# [0.3243 0.3257 0.325 ]
# Micro Average Precision, Recall and F1 Score
# [0.3257 0.3257 0.3257]
#
#
# 20
# Accuracy on Dev Set =  0.38666666666666666
# Precision per Class
# [0.5711 0.5085 0.    ]
# Recall per Class
# [0.562 0.598 0.   ]
# F1 Score per Class
# [0.5665 0.5496    nan]
# Macro Average Precision, Recall and F1 Score
# [0.3599 0.3867 0.3728]
# Micro Average Precision, Recall and F1 Score
# [0.3867 0.3867 0.3867]
#
#
# 40
# Accuracy on Dev Set =  0.41933333333333334
# Precision per Class
# [0.6251 0.4945 0.    ]
# Recall per Class
# [0.677 0.581 0.   ]
# F1 Score per Class
# [0.65   0.5343    nan]
# Macro Average Precision, Recall and F1 Score
# [0.3732 0.4193 0.3949]
# Micro Average Precision, Recall and F1 Score
# [0.4193 0.4193 0.4193]
#
#
# 80
# Accuracy on Dev Set =  0.42233333333333334
# Precision per Class
# [0.6329 0.4907 0.    ]
# Recall per Class
# [0.688 0.579 0.   ]
# F1 Score per Class
# [0.6593 0.5312    nan]
# Macro Average Precision, Recall and F1 Score
# [0.3745 0.4223 0.397 ]
# Micro Average Precision, Recall and F1 Score
# [0.4223 0.4223 0.4223]
#
#
# 100
# Accuracy on Dev Set =  0.42233333333333334
# Precision per Class
# [0.6329 0.4907 0.    ]
# Recall per Class
# [0.688 0.579 0.   ]
# F1 Score per Class
# [0.6593 0.5312    nan]
# Macro Average Precision, Recall and F1 Score
# [0.3745 0.4223 0.397 ]
# Micro Average Precision, Recall and F1 Score
# [0.4223 0.4223 0.4223]
#
#
# 200
# F:\Study\7th Sem\ELL 409\Assignment 1\ELL409_Assign_1\src\performance_util.py:34: RuntimeWarning: invalid value encountered in true_divide
#   return 2*recall*precision/(recall + precision)
# Accuracy on Dev Set =  0.42233333333333334
# Precision per Class
# [0.6329 0.4907 0.    ]
# Recall per Class
# [0.688 0.579 0.   ]
# F1 Score per Class
# [0.6593 0.5312    nan]
# Macro Average Precision, Recall and F1 Score
# [0.3745 0.4223 0.397 ]
# Micro Average Precision, Recall and F1 Score
# [0.4223 0.4223 0.4223]
#
#
# 300
# Accuracy on Dev Set =  0.42233333333333334
# Precision per Class
# [0.6329 0.4907 0.    ]
# Recall per Class
# [0.688 0.579 0.   ]
# F1 Score per Class
# [0.6593 0.5312    nan]
# Macro Average Precision, Recall and F1 Score
# [0.3745 0.4223 0.397 ]
# Micro Average Precision, Recall and F1 Score
# [0.4223 0.4223 0.4223]
#
#
# 500
# Accuracy on Dev Set =  0.42233333333333334
# Precision per Class
# [0.6329 0.4907 0.    ]
# Recall per Class
# [0.688 0.579 0.   ]
# F1 Score per Class
# [0.6593 0.5312    nan]
# Macro Average Precision, Recall and F1 Score
# [0.3745 0.4223 0.397 ]
# Micro Average Precision, Recall and F1 Score
# [0.4223 0.4223 0.4223]
#
#
# 750
# Accuracy on Dev Set =  0.42233333333333334
# Precision per Class
# [0.6329 0.4907 0.    ]
# Recall per Class
# [0.688 0.579 0.   ]
# F1 Score per Class
# [0.6593 0.5312    nan]
# Macro Average Precision, Recall and F1 Score
# [0.3745 0.4223 0.397 ]
# Micro Average Precision, Recall and F1 Score
# [0.4223 0.4223 0.4223]
#
#
# 1000
# Accuracy on Dev Set =  0.42233333333333334
# Precision per Class
# [0.6329 0.4907 0.    ]
# Recall per Class
# [0.688 0.579 0.   ]
# F1 Score per Class
# [0.6593 0.5312    nan]
# Macro Average Precision, Recall and F1 Score
# [0.3745 0.4223 0.397 ]
# Micro Average Precision, Recall and F1 Score
# [0.4223 0.4223 0.4223]
#
#
# 2000
# Accuracy on Dev Set =  0.42233333333333334
# Precision per Class
# [0.6329 0.4907 0.    ]
# Recall per Class
# [0.688 0.579 0.   ]
# F1 Score per Class
# [0.6593 0.5312    nan]
# Macro Average Precision, Recall and F1 Score
# [0.3745 0.4223 0.397 ]
# Micro Average Precision, Recall and F1 Score
# [0.4223 0.4223 0.4223]
#
#
# 5000
# Accuracy on Dev Set =  0.42233333333333334
# Precision per Class
# [0.6329 0.4907 0.    ]
# Recall per Class
# [0.688 0.579 0.   ]
# F1 Score per Class
# [0.6593 0.5312    nan]
# Macro Average Precision, Recall and F1 Score
# [0.3745 0.4223 0.397 ]
# Micro Average Precision, Recall and F1 Score
# [0.4223 0.4223 0.4223]
#
#
# 10000
# Accuracy on Dev Set =  0.42233333333333334
# Precision per Class
# [0.6329 0.4907 0.    ]
# Recall per Class
# [0.688 0.579 0.   ]
# F1 Score per Class
# [0.6593 0.5312    nan]
# Macro Average Precision, Recall and F1 Score
# [0.3745 0.4223 0.397 ]
# Micro Average Precision, Recall and F1 Score
# [0.4223 0.4223 0.4223]

# %% [markdown]
# # Perceptron Model

# %%
model = pm.perceptron_model(1, 3, 1)
w = model.train(X_train, Y_train)
Y_pred = model.predict(X_dev, w).reshape((750, 1))
print("Accuracy on Dev Set = ", pu.model_accuracy(Y_pred, Y_dev))
print("Precision per Class")
print(pu.model_precision(Y_pred, Y_dev, 3).T[0, :])
print("Recall per Class")
print(pu.model_recall(Y_pred, Y_dev, 3).T[0, :])
print("F1 Score per Class")
print(pu.model_f1(Y_pred, Y_dev, 3).T[0, :])
print("Macro Average Precision, Recall and F1 Score")
print(pu.model_macro_average(Y_pred, Y_dev, 3))
print("Micro Average Precision, Recall and F1 Score")
print(pu.model_micro_average(Y_pred, Y_dev, 3))
# Out:
# 0
# 1
# 2
# Accuracy on Dev Set =  0.6786666666666666
# Precision per Class
# [0.7163 0.6493 0.6811]
# Recall per Class
# [0.5984 0.703  0.7362]
# F1 Score per Class
# [0.6521 0.6751 0.7076]
# Macro Average Precision, Recall and F1 Score
# [0.6823 0.6792 0.6807]
# Micro Average Precision, Recall and F1 Score
# [0.6787 0.6787 0.6787]

# %% [markdown]
# # FLDA

# %%
model = flda.flda(3)
model.train(X_train, Y_train)
Y_pred = model.predict(X_test)
print("Accuracy on Dev Set = ", pu.model_accuracy(Y_pred, Y_test))
print("Precision per Class")
print(pu.model_precision(Y_pred, Y_test, 3).T[0, :])
print("Recall per Class")
print(pu.model_recall(Y_pred, Y_test, 3).T[0, :])
print("F1 Score per Class")
print(pu.model_f1(Y_pred, Y_test, 3).T[0, :])
print("Macro Average Precision, Recall and F1 Score")
print(pu.model_macro_average(Y_pred, Y_test, 3))
print("Micro Average Precision, Recall and F1 Score")
print(pu.model_micro_average(Y_pred, Y_test, 3))
# Out:
# Accuracy on Dev Set =  0.811
# Precision per Class
# [0.9129 0.7406 0.797 ]
# Recall per Class
# [0.838 0.845 0.75 ]
# F1 Score per Class
# [0.8738 0.7894 0.7728]
# Macro Average Precision, Recall and F1 Score
# [0.8168 0.811  0.8139]
# Micro Average Precision, Recall and F1 Score
# [0.811 0.811 0.811]

# %% [markdown]
# # SVM
# ### Linear Kernel

# %%
kernels = ['linear', 'rbf', 'poly', 'sigmoid']
for ker in kernels:
    model = svm.SVC(kernel = ker)
    model.fit(X_train, Y_train)
    Y_pred = (model.predict(X_dev)).reshape((750, 1))
    
    print(ker)
    print("Accuracy on Dev Set = ", pu.model_accuracy(Y_pred, Y_dev))
    print("Precision per Class")
    print(pu.model_precision(Y_pred, Y_dev, 3).T[0, :])
    print("Recall per Class")
    print(pu.model_recall(Y_pred, Y_dev, 3).T[0, :])
    print("F1 Score per Class")
    print(pu.model_f1(Y_pred, Y_dev, 3).T[0, :])
    print("Macro Average Precision, Recall and F1 Score")
    print(pu.model_macro_average(Y_pred, Y_dev, 3))
    print("Micro Average Precision, Recall and F1 Score")
    print(pu.model_micro_average(Y_pred, Y_dev, 3))
    
    print()
    print()
# Out:
# f:\study\projects\btp\btp\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# linear
# Accuracy on Dev Set =  0.84
# Precision per Class
# [0.9904 0.7855 0.7782]
# Recall per Class
# [0.8273 0.8947 0.7915]
# F1 Score per Class
# [0.9015 0.8366 0.7848]
# Macro Average Precision, Recall and F1 Score
# [0.8514 0.8378 0.8446]
# Micro Average Precision, Recall and F1 Score
# [0.84 0.84 0.84]
#
#
# rbf
# Accuracy on Dev Set =  0.8813333333333333
# Precision per Class
# [1.     0.8237 0.8515]
# Recall per Class
# [0.8394 0.9662 0.8298]
# F1 Score per Class
# [0.9127 0.8893 0.8405]
# Macro Average Precision, Recall and F1 Score
# [0.8917 0.8784 0.885 ]
# Micro Average Precision, Recall and F1 Score
# [0.8813 0.8813 0.8813]
#
#
# poly
# Accuracy on Dev Set =  0.828
# Precision per Class
# [0.9788 0.8589 0.7125]
# Recall per Class
# [0.743  0.8008 0.9489]
# F1 Score per Class
# [0.8447 0.8288 0.8139]
# Macro Average Precision, Recall and F1 Score
# [0.8501 0.8309 0.8404]
# Micro Average Precision, Recall and F1 Score
# [0.828 0.828 0.828]
#
#
# sigmoid
# Accuracy on Dev Set =  0.7173333333333334
# Precision per Class
# [0.6786 0.8278 0.6695]
# Recall per Class
# [0.8394 0.6504 0.6638]
# F1 Score per Class
# [0.7504 0.7284 0.6667]
# Macro Average Precision, Recall and F1 Score
# [0.7253 0.7179 0.7215]
# Micro Average Precision, Recall and F1 Score
# [0.7173 0.7173 0.7173]
